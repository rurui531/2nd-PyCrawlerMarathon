# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text

import json

json.loads(r.text)
# Out:
# [{'id': '11642942484',
#   'type': 'PushEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 243947393,
#    'name': 'direwolf-github/my-app-45dcc47b',
#    'url': 'https://api.github.com/repos/direwolf-github/my-app-45dcc47b'},
#   'payload': {'push_id': 4699218502,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/branch-95309cd9',
#    'head': 'f3132c39d0516d185da15e37b9f2b706fe9bdb1d',
#    'before': 'e0f50f161d8ab286da26a5eb3ebf5ffb5a53a32b',
#    'commits': [{'sha': 'f3132c39d0516d185da15e37b9f2b706fe9bdb1d',
#      'author': {'email': 'heroku-lifecycle+direwolf-github@salesforce.com',
#       'name': 'direwolf-github'},
#      'message': 'add readme.txt',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/direwolf-github/my-app-45dcc47b/commits/f3132c39d0516d185da15e37b9f2b706fe9bdb1d'}]},
#   'public': True,
#   'created_at': '2020-02-29T10:21:47Z'},
#  {'id': '11642942482',
#   'type': 'CreateEvent',
#   'actor': {'id': 60733546,
#    'login': 'Oceloott',
#    'display_login': 'Oceloott',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Oceloott',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60733546?'},
#   'repo': {'id': 243943665,
#    'name': 'Oceloott/ChatClient',
#    'url': 'https://api.github.com/repos/Oceloott/ChatClient'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-29T10:21:47Z'},
#  {'id': '11642942476',
#   'type': 'CreateEvent',
#   'actor': {'id': 15162371,
#    'login': 'muratgozel',
#    'display_login': 'muratgozel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/muratgozel',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15162371?'},
#   'repo': {'id': 235083680,
#    'name': 'basekits/kit-dom',
#    'url': 'https://api.github.com/repos/basekits/kit-dom'},
#   'payload': {'ref': '1.2.2',
#    'ref_type': 'tag',
#    'master_branch': 'master',
#    'description': 'DOM utility functions kit for basekits.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-29T10:21:47Z',
#   'org': {'id': 60067174,
#    'login': 'basekits',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/basekits',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60067174?'}},
#  {'id': '11642942475',
#   'type': 'IssuesEvent',
#   'actor': {'id': 44796949,
#    'login': 'iraklal',
#    'display_login': 'iraklal',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/iraklal',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44796949?'},
#   'repo': {'id': 19358114,
#    'name': 'night/BetterTTV',
#    'url': 'https://api.github.com/repos/night/BetterTTV'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/night/BetterTTV/issues/3771',
#     'repository_url': 'https://api.github.com/repos/night/BetterTTV',
#     'labels_url': 'https://api.github.com/repos/night/BetterTTV/issues/3771/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/night/BetterTTV/issues/3771/comments',
#     'events_url': 'https://api.github.com/repos/night/BetterTTV/issues/3771/events',
#     'html_url': 'https://github.com/night/BetterTTV/issues/3771',
#     'id': 573268423,
#     'node_id': 'MDU6SXNzdWU1NzMyNjg0MjM=',
#     'number': 3771,
#     'title': 'Picture in Picture mode',
#     'user': {'login': 'iraklal',
#      'id': 44796949,
#      'node_id': 'MDQ6VXNlcjQ0Nzk2OTQ5',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/44796949?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/iraklal',
#      'html_url': 'https://github.com/iraklal',
#      'followers_url': 'https://api.github.com/users/iraklal/followers',
#      'following_url': 'https://api.github.com/users/iraklal/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/iraklal/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/iraklal/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/iraklal/subscriptions',
#      'organizations_url': 'https://api.github.com/users/iraklal/orgs',
#      'repos_url': 'https://api.github.com/users/iraklal/repos',
#      'events_url': 'https://api.github.com/users/iraklal/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/iraklal/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-02-29T10:20:58Z',
#     'updated_at': '2020-02-29T10:21:47Z',
#     'closed_at': '2020-02-29T10:21:47Z',
#     'author_association': 'NONE',
#     'body': 'Add button to disabe Picture in Picture mode, please. '}},
#   'public': True,
#   'created_at': '2020-02-29T10:21:47Z'},
#  {'id': '11642942473',
#   'type': 'CreateEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 243947397,
#    'name': 'direwolf-github/my-app-62fbb006',
#    'url': 'https://api.github.com/repos/direwolf-github/my-app-62fbb006'},
#   'payload': {'ref': 'branch-a59f5300',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-29T10:21:47Z'},
#  {'id': '11642942468',
#   'type': 'PushEvent',
#   'actor': {'id': 6896443,
#    'login': 'dyedgreen',
#    'display_login': 'dyedgreen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dyedgreen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6896443?'},
#   'repo': {'id': 242818471,
#    'name': 'aihack20/nhs_challenge',
#    'url': 'https://api.github.com/repos/aihack20/nhs_challenge'},
#   'payload': {'push_id': 4699218492,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '9338fd0cb96cf8fc15367a79341ccce4e9ff4a33',
#    'before': 'a21aaadaca32da24a7aed61096e18544ed62ccfc',
#    'commits': [{'sha': '9338fd0cb96cf8fc15367a79341ccce4e9ff4a33',
#      'author': {'email': 'dyed.green.info@gmail.com', 'name': 'Tilman Roeder'},
#      'message': 'Add extra data-set',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/aihack20/nhs_challenge/commits/9338fd0cb96cf8fc15367a79341ccce4e9ff4a33'}]},
#   'public': True,
#   'created_at': '2020-02-29T10:21:47Z'},
#  {'id': '11642942467',
#   'type': 'CreateEvent',
#   'actor': {'id': 24291662,
#    'login': 'sandreae',
#    'display_login': 'sandreae',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sandreae',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24291662?'},
#   'repo': {'id': 86197865,
#    'name': 'adzialocha/hoffnung3000',
#    'url': 'https://api.github.com/repos/adzialocha/hoffnung3000'},
#   'payload': {'ref': 'antiuniFeature/disableDerMarkt',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Platform for decentralized, anonymized, self-curated festivals',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-29T10:21:47Z'},
#  {'id': '11642942465',
#   'type': 'PushEvent',
#   'actor': {'id': 58101727,
#    'login': 'howardn23',
#    'display_login': 'howardn23',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/howardn23',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58101727?'},
#   'repo': {'id': 223544869,
#    'name': 'howardn23/yanggang',
#    'url': 'https://api.github.com/repos/howardn23/yanggang'},
#   'payload': {'push_id': 4699218487,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '15737cd6ff4359fec4fabc3418673ee00451754e',
#    'before': '7ab6714ea3b1a069f5bc09938a98efe7de90fc37',
#    'commits': [{'sha': '15737cd6ff4359fec4fabc3418673ee00451754e',
#      'author': {'email': 'howardnguyen23@gmail.com', 'name': 'howardn23'},
#      'message': 'updating values',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/howardn23/yanggang/commits/15737cd6ff4359fec4fabc3418673ee00451754e'}]},
#   'public': True,
#   'created_at': '2020-02-29T10:21:47Z'},
#  {'id': '11642942464',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 46594739,
#    'name': 'Lombiq/Associativy-Taxonomies-Adapter',
#    'url': 'https://api.github.com/repos/Lombiq/Associativy-Taxonomies-Adapter'},
#   'payload': {'push_id': 4699218489,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/orchard-upgrade-1.10.1',
#    'head': '37ced8f2e795e8e4e96f435a52f6ef094b4c42a6',
#    'before': '37ced8f2e795e8e4e96f435a52f6ef094b4c42a6',
#    'commits': []},
#   'public': True,
#   'created_at': '2020-02-29T10:21:47Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '11642942460',
#   'type': 'PushEvent',
#   'actor': {'id': 1621419,
#    'login': 'Rming',
#    'display_login': 'Rming',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Rming',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1621419?'},
#   'repo': {'id': 210516894,
#    'name': 'Rming/sync_openpilot',
#    'url': 'https://api.github.com/repos/Rming/sync_openpilot'},
#   'payload': {'push_id': 4699218483,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '326aaaa1b4103e7d609353d2d7290e3009aee967',
#    'before': '2f0728a7ecf3f9d855b6b528b63197841d1869b8',
#    'commits': [{'sha': '326aaaa1b4103e7d609353d2d7290e3009aee967',
#      'author': {'email': 'rmingwang@gmail.com', 'name': 'Rming'},
#      'message': '新增raspberry-pilot',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Rming/sync_openpilot/commits/326aaaa1b4103e7d609353d2d7290e3009aee967'}]},
#   'public': True,
#   'created_at': '2020-02-29T10:21:47Z'},
#  {'id': '11642942459',
#   'type': 'PushEvent',
#   'actor': {'id': 12509673,
#    'login': 'peterzuger',
#    'display_login': 'peterzuger',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/peterzuger',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12509673?'},
#   'repo': {'id': 210125747,
#    'name': 'peterzuger/dotfiles',
#    'url': 'https://api.github.com/repos/peterzuger/dotfiles'},
#   'payload': {'push_id': 4699218485,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '0b620c825fe16ecf699eff41ea92a5feef1ee18c',
#    'before': '4d4069fa35b39add916f6047eb38b8705458070d',
#    'commits': [{'sha': '0b620c825fe16ecf699eff41ea92a5feef1ee18c',
#      'author': {'email': 'zueger.peter@icloud.com', 'name': 'Peter Züger'},
#      'message': "modified virtualbox config\n\nchanged Background image\nVirtualbox has no battery's\nchanged the modifier key (Mod4 is captured by the Host)\nno mail and gpg\nVirtualbox has no vsync\ndisable shadow and blur for performance reasons\nnot using the there tool in Virtualbox\nremoved nouveau setting from grub cmdline",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/peterzuger/dotfiles/commits/0b620c825fe16ecf699eff41ea92a5feef1ee18c'}]},
#   'public': True,
#   'created_at': '2020-02-29T10:21:47Z'},
#  {'id': '11642942462',
#   'type': 'CreateEvent',
#   'actor': {'id': 651128,
#    'login': 'Neverlord',
#    'display_login': 'Neverlord',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Neverlord',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/651128?'},
#   'repo': {'id': 21657085,
#    'name': 'zeek/broker',
#    'url': 'https://api.github.com/repos/zeek/broker'},
#   'payload': {'ref': 'topic/neverlord/store-updates',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': "Zeek's Messaging Library",
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-29T10:21:47Z',
#   'org': {'id': 1194067,
#    'login': 'zeek',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/zeek',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1194067?'}},
#  {'id': '11642942458',
#   'type': 'WatchEvent',
#   'actor': {'id': 980367,
#    'login': 'aliou',
#    'display_login': 'aliou',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aliou',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/980367?'},
#   'repo': {'id': 238967781,
#    'name': 'AvdLee/Poes',
#    'url': 'https://api.github.com/repos/AvdLee/Poes'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-02-29T10:21:47Z'},
#  {'id': '11642942453',
#   'type': 'PushEvent',
#   'actor': {'id': 18453927,
#    'login': 'lewiswu1209',
#    'display_login': 'lewiswu1209',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lewiswu1209',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18453927?'},
#   'repo': {'id': 240036196,
#    'name': 'lewiswu1209/Heimdall',
#    'url': 'https://api.github.com/repos/lewiswu1209/Heimdall'},
#   'payload': {'push_id': 4699218482,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1344042fa88564e41a158fbb400e3bef258a97c4',
#    'before': 'f7ee83d1084c717f914c81472eb269d9b56cbc4f',
#    'commits': [{'sha': '1344042fa88564e41a158fbb400e3bef258a97c4',
#      'author': {'email': 'lewiswu1209@163.com', 'name': 'lewiswu1209'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lewiswu1209/Heimdall/commits/1344042fa88564e41a158fbb400e3bef258a97c4'}]},
#   'public': True,
#   'created_at': '2020-02-29T10:21:47Z'},
#  {'id': '11642942450',
#   'type': 'CreateEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 183051410,
#    'name': 'direwolf-github/my-app',
#    'url': 'https://api.github.com/repos/direwolf-github/my-app'},
#   'payload': {'ref': 'branch-b63ccf97',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-29T10:21:46Z'},
#  {'id': '11642942449',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 1573684,
#    'login': 'adangel',
#    'display_login': 'adangel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/adangel',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1573684?'},
#   'repo': {'id': 4992906,
#    'name': 'pmd/pmd',
#    'url': 'https://api.github.com/repos/pmd/pmd'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/pmd/pmd/pulls/comments/386018188',
#     'pull_request_review_id': 366789551,
#     'id': 386018188,
#     'node_id': 'MDI0OlB1bGxSZXF1ZXN0UmV2aWV3Q29tbWVudDM4NjAxODE4OA==',
#     'diff_hunk': '@@ -1015,4 +1015,10 @@\n         <module>pmd-doc</module>\n         <module>pmd-lang-test</module>\n     </modules>\n+    <dependencies>',
#     'path': 'pom.xml',
#     'position': 4,
#     'original_position': 4,
#     'commit_id': '57279e11dbc6a2e4b68e138bbe6dfc2fda95ba34',
#     'original_commit_id': '57279e11dbc6a2e4b68e138bbe6dfc2fda95ba34',
#     'user': {'login': 'adangel',
#      'id': 1573684,
#      'node_id': 'MDQ6VXNlcjE1NzM2ODQ=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/1573684?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/adangel',
#      'html_url': 'https://github.com/adangel',
#      'followers_url': 'https://api.github.com/users/adangel/followers',
#      'following_url': 'https://api.github.com/users/adangel/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/adangel/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/adangel/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/adangel/subscriptions',
#      'organizations_url': 'https://api.github.com/users/adangel/orgs',
#      'repos_url': 'https://api.github.com/users/adangel/repos',
#      'events_url': 'https://api.github.com/users/adangel/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/adangel/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'We should not need this dependency.... please remove it again.',
#     'created_at': '2020-02-29T10:21:32Z',
#     'updated_at': '2020-02-29T10:21:46Z',
#     'html_url': 'https://github.com/pmd/pmd/pull/2312#discussion_r386018188',
#     'pull_request_url': 'https://api.github.com/repos/pmd/pmd/pulls/2312',
#     'author_association': 'MEMBER',
#     '_links': {'self': {'href': 'https://api.github.com/repos/pmd/pmd/pulls/comments/386018188'},
#      'html': {'href': 'https://github.com/pmd/pmd/pull/2312#discussion_r386018188'},
#      'pull_request': {'href': 'https://api.github.com/repos/pmd/pmd/pulls/2312'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/pmd/pmd/pulls/2312',
#     'id': 379729118,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0Mzc5NzI5MTE4',
#     'html_url': 'https://github.com/pmd/pmd/pull/2312',
#     'diff_url': 'https://github.com/pmd/pmd/pull/2312.diff',
#     'patch_url': 'https://github.com/pmd/pmd/pull/2312.patch',
#     'issue_url': 'https://api.github.com/repos/pmd/pmd/issues/2312',
#     'number': 2312,
#     'state': 'open',
#     'locked': False,
#     'title': '[apex] Update ApexCRUDViolation Rule',
#     'user': {'login': 'jarquile',
#      'id': 16008477,
#      'node_id': 'MDQ6VXNlcjE2MDA4NDc3',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/16008477?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jarquile',
#      'html_url': 'https://github.com/jarquile',
#      'followers_url': 'https://api.github.com/users/jarquile/followers',
#      'following_url': 'https://api.github.com/users/jarquile/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jarquile/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jarquile/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jarquile/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jarquile/orgs',
#      'repos_url': 'https://api.github.com/users/jarquile/repos',
#      'events_url': 'https://api.github.com/users/jarquile/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jarquile/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "**PR Description:**\r\n\r\nUpdating This rule to support the new feature 'WITH SECURITY_ENFORCED'.  To learn more about this feature go to (https://developer.salesforce.com/docs/atlas.en-us.apexcode.meta/apexcode/apex_classes_with_security_enforced.htm).\r\n\r\nThis fixes #2210.",
#     'created_at': '2020-02-25T18:19:50Z',
#     'updated_at': '2020-02-29T10:21:46Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '253bc64cdf2bd945110ed7c553767cc777f368a7',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/pmd/pmd/pulls/2312/commits',
#     'review_comments_url': 'https://api.github.com/repos/pmd/pmd/pulls/2312/comments',
#     'review_comment_url': 'https://api.github.com/repos/pmd/pmd/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/pmd/pmd/issues/2312/comments',
#     'statuses_url': 'https://api.github.com/repos/pmd/pmd/statuses/57279e11dbc6a2e4b68e138bbe6dfc2fda95ba34',
#     'head': {'label': 'jarquile:UpdateCRUDRule',
#      'ref': 'UpdateCRUDRule',
#      'sha': '57279e11dbc6a2e4b68e138bbe6dfc2fda95ba34',
#      'user': {'login': 'jarquile',
#       'id': 16008477,
#       'node_id': 'MDQ6VXNlcjE2MDA4NDc3',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/16008477?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/jarquile',
#       'html_url': 'https://github.com/jarquile',
#       'followers_url': 'https://api.github.com/users/jarquile/followers',
#       'following_url': 'https://api.github.com/users/jarquile/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jarquile/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jarquile/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jarquile/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jarquile/orgs',
#       'repos_url': 'https://api.github.com/users/jarquile/repos',
#       'events_url': 'https://api.github.com/users/jarquile/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/jarquile/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 240120817,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNDAxMjA4MTc=',
#       'name': 'pmd',
#       'full_name': 'jarquile/pmd',
#       'private': False,
#       'owner': {'login': 'jarquile',
#        'id': 16008477,
#        'node_id': 'MDQ6VXNlcjE2MDA4NDc3',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/16008477?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/jarquile',
#        'html_url': 'https://github.com/jarquile',
#        'followers_url': 'https://api.github.com/users/jarquile/followers',
#        'following_url': 'https://api.github.com/users/jarquile/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/jarquile/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/jarquile/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/jarquile/subscriptions',
#        'organizations_url': 'https://api.github.com/users/jarquile/orgs',
#        'repos_url': 'https://api.github.com/users/jarquile/repos',
#        'events_url': 'https://api.github.com/users/jarquile/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/jarquile/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/jarquile/pmd',
#       'description': 'An extensible multilanguage static code analyzer.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/jarquile/pmd',
#       'forks_url': 'https://api.github.com/repos/jarquile/pmd/forks',
#       'keys_url': 'https://api.github.com/repos/jarquile/pmd/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/jarquile/pmd/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/jarquile/pmd/teams',
#       'hooks_url': 'https://api.github.com/repos/jarquile/pmd/hooks',
#       'issue_events_url': 'https://api.github.com/repos/jarquile/pmd/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/jarquile/pmd/events',
#       'assignees_url': 'https://api.github.com/repos/jarquile/pmd/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/jarquile/pmd/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/jarquile/pmd/tags',
#       'blobs_url': 'https://api.github.com/repos/jarquile/pmd/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/jarquile/pmd/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/jarquile/pmd/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/jarquile/pmd/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/jarquile/pmd/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/jarquile/pmd/languages',
#       'stargazers_url': 'https://api.github.com/repos/jarquile/pmd/stargazers',
#       'contributors_url': 'https://api.github.com/repos/jarquile/pmd/contributors',
#       'subscribers_url': 'https://api.github.com/repos/jarquile/pmd/subscribers',
#       'subscription_url': 'https://api.github.com/repos/jarquile/pmd/subscription',
#       'commits_url': 'https://api.github.com/repos/jarquile/pmd/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/jarquile/pmd/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/jarquile/pmd/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/jarquile/pmd/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/jarquile/pmd/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/jarquile/pmd/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/jarquile/pmd/merges',
#       'archive_url': 'https://api.github.com/repos/jarquile/pmd/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/jarquile/pmd/downloads',
#       'issues_url': 'https://api.github.com/repos/jarquile/pmd/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/jarquile/pmd/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/jarquile/pmd/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/jarquile/pmd/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/jarquile/pmd/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/jarquile/pmd/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/jarquile/pmd/deployments',
#       'created_at': '2020-02-12T21:39:20Z',
#       'updated_at': '2020-02-12T21:39:21Z',
#       'pushed_at': '2020-02-28T22:21:58Z',
#       'git_url': 'git://github.com/jarquile/pmd.git',
#       'ssh_url': 'git@github.com:jarquile/pmd.git',
#       'clone_url': 'https://github.com/jarquile/pmd.git',
#       'svn_url': 'https://github.com/jarquile/pmd',
#       'homepage': 'https://pmd.github.io',
#       'size': 301435,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'pmd:master',
#      'ref': 'master',
#      'sha': 'd21e2565ae2aa89cabde1f1c92509b63d6d92149',
#      'user': {'login': 'pmd',
#       'id': 1958157,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE5NTgxNTc=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/1958157?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/pmd',
#       'html_url': 'https://github.com/pmd',
#       'followers_url': 'https://api.github.com/users/pmd/followers',
#       'following_url': 'https://api.github.com/users/pmd/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/pmd/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/pmd/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/pmd/subscriptions',
#       'organizations_url': 'https://api.github.com/users/pmd/orgs',
#       'repos_url': 'https://api.github.com/users/pmd/repos',
#       'events_url': 'https://api.github.com/users/pmd/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/pmd/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 4992906,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk0OTkyOTA2',
#       'name': 'pmd',
#       'full_name': 'pmd/pmd',
#       'private': False,
#       'owner': {'login': 'pmd',
#        'id': 1958157,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE5NTgxNTc=',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/1958157?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/pmd',
#        'html_url': 'https://github.com/pmd',
#        'followers_url': 'https://api.github.com/users/pmd/followers',
#        'following_url': 'https://api.github.com/users/pmd/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/pmd/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/pmd/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/pmd/subscriptions',
#        'organizations_url': 'https://api.github.com/users/pmd/orgs',
#        'repos_url': 'https://api.github.com/users/pmd/repos',
#        'events_url': 'https://api.github.com/users/pmd/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/pmd/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/pmd/pmd',
#       'description': 'An extensible multilanguage static code analyzer.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/pmd/pmd',
#       'forks_url': 'https://api.github.com/repos/pmd/pmd/forks',
#       'keys_url': 'https://api.github.com/repos/pmd/pmd/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/pmd/pmd/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/pmd/pmd/teams',
#       'hooks_url': 'https://api.github.com/repos/pmd/pmd/hooks',
#       'issue_events_url': 'https://api.github.com/repos/pmd/pmd/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/pmd/pmd/events',
#       'assignees_url': 'https://api.github.com/repos/pmd/pmd/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/pmd/pmd/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/pmd/pmd/tags',
#       'blobs_url': 'https://api.github.com/repos/pmd/pmd/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/pmd/pmd/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/pmd/pmd/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/pmd/pmd/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/pmd/pmd/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/pmd/pmd/languages',
#       'stargazers_url': 'https://api.github.com/repos/pmd/pmd/stargazers',
#       'contributors_url': 'https://api.github.com/repos/pmd/pmd/contributors',
#       'subscribers_url': 'https://api.github.com/repos/pmd/pmd/subscribers',
#       'subscription_url': 'https://api.github.com/repos/pmd/pmd/subscription',
#       'commits_url': 'https://api.github.com/repos/pmd/pmd/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/pmd/pmd/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/pmd/pmd/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/pmd/pmd/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/pmd/pmd/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/pmd/pmd/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/pmd/pmd/merges',
#       'archive_url': 'https://api.github.com/repos/pmd/pmd/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/pmd/pmd/downloads',
#       'issues_url': 'https://api.github.com/repos/pmd/pmd/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/pmd/pmd/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/pmd/pmd/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/pmd/pmd/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/pmd/pmd/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/pmd/pmd/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/pmd/pmd/deployments',
#       'created_at': '2012-07-11T18:03:00Z',
#       'updated_at': '2020-02-29T09:36:33Z',
#       'pushed_at': '2020-02-29T09:45:02Z',
#       'git_url': 'git://github.com/pmd/pmd.git',
#       'ssh_url': 'git@github.com:pmd/pmd.git',
#       'clone_url': 'https://github.com/pmd/pmd.git',
#       'svn_url': 'https://github.com/pmd/pmd',
#       'homepage': 'https://pmd.github.io',
#       'size': 303786,
#       'stargazers_count': 2716,
#       'watchers_count': 2716,
#       'language': 'Java',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 941,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 360,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 941,
#       'open_issues': 360,
#       'watchers': 2716,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/pmd/pmd/pulls/2312'},
#      'html': {'href': 'https://github.com/pmd/pmd/pull/2312'},
#      'issue': {'href': 'https://api.github.com/repos/pmd/pmd/issues/2312'},
#      'comments': {'href': 'https://api.github.com/repos/pmd/pmd/issues/2312/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/pmd/pmd/pulls/2312/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/pmd/pmd/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/pmd/pmd/pulls/2312/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/pmd/pmd/statuses/57279e11dbc6a2e4b68e138bbe6dfc2fda95ba34'}},
#     'author_association': 'NONE'}},
#   'public': True,
#   'created_at': '2020-02-29T10:21:32Z',
#   'org': {'id': 1958157,
#    'login': 'pmd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/pmd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1958157?'}},
#  {'id': '11642942448',
#   'type': 'PushEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 183051410,
#    'name': 'direwolf-github/my-app',
#    'url': 'https://api.github.com/repos/direwolf-github/my-app'},
#   'payload': {'push_id': 4699218476,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/branch-8c949f68',
#    'head': '13ebed8df26ce6cb59d3071e05a7b80e9631aa2c',
#    'before': '97b657afdf54d3b3ccbcb094fc803fee1c0e5821',
#    'commits': [{'sha': '13ebed8df26ce6cb59d3071e05a7b80e9631aa2c',
#      'author': {'email': 'heroku-lifecycle+direwolf-github@salesforce.com',
#       'name': 'direwolf-github'},
#      'message': 'add readme.txt',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/direwolf-github/my-app/commits/13ebed8df26ce6cb59d3071e05a7b80e9631aa2c'}]},
#   'public': True,
#   'created_at': '2020-02-29T10:21:46Z'},
#  {'id': '11642942447',
#   'type': 'WatchEvent',
#   'actor': {'id': 46416059,
#    'login': 'lemonjie',
#    'display_login': 'lemonjie',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lemonjie',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46416059?'},
#   'repo': {'id': 58028038,
#    'name': '521xueweihan/HelloGitHub',
#    'url': 'https://api.github.com/repos/521xueweihan/HelloGitHub'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-02-29T10:21:46Z'},
#  {'id': '11642942446',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 39925939,
#    'login': 'anastasiya-zhiboedova',
#    'display_login': 'anastasiya-zhiboedova',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/anastasiya-zhiboedova',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39925939?'},
#   'repo': {'id': 241455283,
#    'name': 'anastasiya-zhiboedova/psad-2020',
#    'url': 'https://api.github.com/repos/anastasiya-zhiboedova/psad-2020'},
#   'payload': {'action': 'opened',
#    'number': 1,
#    'pull_request': {'url': 'https://api.github.com/repos/anastasiya-zhiboedova/psad-2020/pulls/1',
#     'id': 381830583,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzgxODMwNTgz',
#     'html_url': 'https://github.com/anastasiya-zhiboedova/psad-2020/pull/1',
#     'diff_url': 'https://github.com/anastasiya-zhiboedova/psad-2020/pull/1.diff',
#     'patch_url': 'https://github.com/anastasiya-zhiboedova/psad-2020/pull/1.patch',
#     'issue_url': 'https://api.github.com/repos/anastasiya-zhiboedova/psad-2020/issues/1',
#     'number': 1,
#     'state': 'open',
#     'locked': False,
#     'title': 'week_2',
#     'user': {'login': 'anastasiya-zhiboedova',
#      'id': 39925939,
#      'node_id': 'MDQ6VXNlcjM5OTI1OTM5',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/39925939?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/anastasiya-zhiboedova',
#      'html_url': 'https://github.com/anastasiya-zhiboedova',
#      'followers_url': 'https://api.github.com/users/anastasiya-zhiboedova/followers',
#      'following_url': 'https://api.github.com/users/anastasiya-zhiboedova/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/anastasiya-zhiboedova/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/anastasiya-zhiboedova/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/anastasiya-zhiboedova/subscriptions',
#      'organizations_url': 'https://api.github.com/users/anastasiya-zhiboedova/orgs',
#      'repos_url': 'https://api.github.com/users/anastasiya-zhiboedova/repos',
#      'events_url': 'https://api.github.com/users/anastasiya-zhiboedova/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/anastasiya-zhiboedova/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2020-02-29T10:21:46Z',
#     'updated_at': '2020-02-29T10:21:46Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/anastasiya-zhiboedova/psad-2020/pulls/1/commits',
#     'review_comments_url': 'https://api.github.com/repos/anastasiya-zhiboedova/psad-2020/pulls/1/comments',
#     'review_comment_url': 'https://api.github.com/repos/anastasiya-zhiboedova/psad-2020/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/anastasiya-zhiboedova/psad-2020/issues/1/comments',
#     'statuses_url': 'https://api.github.com/repos/anastasiya-zhiboedova/psad-2020/statuses/51d725f0e6715c74c8122747642426a0243f1826',
#     'head': {'label': 'Intelligent-Systems-Phystech:master',
#      'ref': 'master',
#      'sha': '51d725f0e6715c74c8122747642426a0243f1826',
#      'user': {'login': 'Intelligent-Systems-Phystech',
#       'id': 36991821,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM2OTkxODIx',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/36991821?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Intelligent-Systems-Phystech',
#       'html_url': 'https://github.com/Intelligent-Systems-Phystech',
#       'followers_url': 'https://api.github.com/users/Intelligent-Systems-Phystech/followers',
#       'following_url': 'https://api.github.com/users/Intelligent-Systems-Phystech/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Intelligent-Systems-Phystech/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Intelligent-Systems-Phystech/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Intelligent-Systems-Phystech/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Intelligent-Systems-Phystech/orgs',
#       'repos_url': 'https://api.github.com/users/Intelligent-Systems-Phystech/repos',
#       'events_url': 'https://api.github.com/users/Intelligent-Systems-Phystech/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Intelligent-Systems-Phystech/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 237831386,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMzc4MzEzODY=',
#       'name': 'psad-2020',
#       'full_name': 'Intelligent-Systems-Phystech/psad-2020',
#       'private': False,
#       'owner': {'login': 'Intelligent-Systems-Phystech',
#        'id': 36991821,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM2OTkxODIx',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/36991821?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Intelligent-Systems-Phystech',
#        'html_url': 'https://github.com/Intelligent-Systems-Phystech',
#        'followers_url': 'https://api.github.com/users/Intelligent-Systems-Phystech/followers',
#        'following_url': 'https://api.github.com/users/Intelligent-Systems-Phystech/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Intelligent-Systems-Phystech/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Intelligent-Systems-Phystech/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Intelligent-Systems-Phystech/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Intelligent-Systems-Phystech/orgs',
#        'repos_url': 'https://api.github.com/users/Intelligent-Systems-Phystech/repos',
#        'events_url': 'https://api.github.com/users/Intelligent-Systems-Phystech/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Intelligent-Systems-Phystech/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/Intelligent-Systems-Phystech/psad-2020',
#       'description': 'Курс по методам прикладного статистического анализа данных, 2020',
#       'fork': False,
#       'url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020',
#       'forks_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/forks',
#       'keys_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/teams',
#       'hooks_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/events',
#       'assignees_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/tags',
#       'blobs_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/languages',
#       'stargazers_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/subscription',
#       'commits_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/merges',
#       'archive_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/downloads',
#       'issues_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Intelligent-Systems-Phystech/psad-2020/deployments',
#       'created_at': '2020-02-02T20:23:53Z',
#       'updated_at': '2020-02-26T16:01:36Z',
#       'pushed_at': '2020-02-26T16:01:34Z',
#       'git_url': 'git://github.com/Intelligent-Systems-Phystech/psad-2020.git',
#       'ssh_url': 'git@github.com:Intelligent-Systems-Phystech/psad-2020.git',
#       'clone_url': 'https://github.com/Intelligent-Systems-Phystech/psad-2020.git',
#       'svn_url': 'https://github.com/Intelligent-Systems-Phystech/psad-2020',
#       'homepage': None,
#       'size': 32430,
#       'stargazers_count': 3,
#       'watchers_count': 3,
#       'language': 'Jupyter Notebook',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 8,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'forks': 8,
#       'open_issues': 0,
#       'watchers': 3,
#       'default_branch': 'master'}},
#     'base': {'label': 'anastasiya-zhiboedova:master',
#      'ref': 'master',
#      'sha': 'da4f26a3a47cff1b55e6942fd4f1fdad7768af8e',
#      'user': {'login': 'anastasiya-zhiboedova',
#       'id': 39925939,
#       'node_id': 'MDQ6VXNlcjM5OTI1OTM5',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/39925939?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/anastasiya-zhiboedova',
#       'html_url': 'https://github.com/anastasiya-zhiboedova',
#       'followers_url': 'https://api.github.com/users/anastasiya-zhiboedova/followers',
#       'following_url': 'https://api.github.com/users/anastasiya-zhiboedova/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/anastasiya-zhiboedova/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/anastasiya-zhiboedova/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/anastasiya-zhiboedova/subscriptions',
#       'organizations_url': 'https://api.github.com/users/anastasiya-zhiboedova/orgs',
#       'repos_url': 'https://api.github.com/users/anastasiya-zhiboedova/repos',
#       'events_url': 'https://api.github.com/users/anastasiya-zhiboedova/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/anastasiya-zhiboedova/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 241455283,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNDE0NTUyODM=',
# ...
#       'git_tags_url': 'https://api.github.com/repos/pmd/pmd/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/pmd/pmd/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/pmd/pmd/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/pmd/pmd/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/pmd/pmd/languages',
#       'stargazers_url': 'https://api.github.com/repos/pmd/pmd/stargazers',
#       'contributors_url': 'https://api.github.com/repos/pmd/pmd/contributors',
#       'subscribers_url': 'https://api.github.com/repos/pmd/pmd/subscribers',
#       'subscription_url': 'https://api.github.com/repos/pmd/pmd/subscription',
#       'commits_url': 'https://api.github.com/repos/pmd/pmd/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/pmd/pmd/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/pmd/pmd/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/pmd/pmd/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/pmd/pmd/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/pmd/pmd/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/pmd/pmd/merges',
#       'archive_url': 'https://api.github.com/repos/pmd/pmd/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/pmd/pmd/downloads',
#       'issues_url': 'https://api.github.com/repos/pmd/pmd/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/pmd/pmd/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/pmd/pmd/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/pmd/pmd/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/pmd/pmd/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/pmd/pmd/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/pmd/pmd/deployments',
#       'created_at': '2012-07-11T18:03:00Z',
#       'updated_at': '2020-02-29T09:36:33Z',
#       'pushed_at': '2020-02-29T09:45:02Z',
#       'git_url': 'git://github.com/pmd/pmd.git',
#       'ssh_url': 'git@github.com:pmd/pmd.git',
#       'clone_url': 'https://github.com/pmd/pmd.git',
#       'svn_url': 'https://github.com/pmd/pmd',
#       'homepage': 'https://pmd.github.io',
#       'size': 303786,
#       'stargazers_count': 2716,
#       'watchers_count': 2716,
#       'language': 'Java',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 941,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 360,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 941,
#       'open_issues': 360,
#       'watchers': 2716,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/pmd/pmd/pulls/2312'},
#      'html': {'href': 'https://github.com/pmd/pmd/pull/2312'},
#      'issue': {'href': 'https://api.github.com/repos/pmd/pmd/issues/2312'},
#      'comments': {'href': 'https://api.github.com/repos/pmd/pmd/issues/2312/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/pmd/pmd/pulls/2312/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/pmd/pmd/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/pmd/pmd/pulls/2312/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/pmd/pmd/statuses/57279e11dbc6a2e4b68e138bbe6dfc2fda95ba34'}},
#     'author_association': 'NONE'}},
#   'public': True,
#   'created_at': '2020-02-29T10:20:34Z',
#   'org': {'id': 1958157,
#    'login': 'pmd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/pmd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1958157?'}},
#  {'id': '11642942440',
#   'type': 'WatchEvent',
#   'actor': {'id': 32785236,
#    'login': 'yoxf',
#    'display_login': 'yoxf',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yoxf',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32785236?'},
#   'repo': {'id': 145668047,
#    'name': 'rdlabo/serverless-nestjs',
#    'url': 'https://api.github.com/repos/rdlabo/serverless-nestjs'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-02-29T10:21:46Z'},
#  {'id': '11642942443',
#   'type': 'CreateEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 243947393,
#    'name': 'direwolf-github/my-app-45dcc47b',
#    'url': 'https://api.github.com/repos/direwolf-github/my-app-45dcc47b'},
#   'payload': {'ref': 'branch-95309cd9',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-29T10:21:46Z'},
#  {'id': '11642942438',
#   'type': 'CreateEvent',
#   'actor': {'id': 22294942,
#    'login': 'hkahfakh',
#    'display_login': 'hkahfakh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hkahfakh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22294942?'},
#   'repo': {'id': 243947386,
#    'name': 'hkahfakh/Controler1',
#    'url': 'https://api.github.com/repos/hkahfakh/Controler1'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-29T10:21:46Z'},
#  {'id': '11642942436',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 49554844,
#    'login': 'hcsp-bot',
#    'display_login': 'hcsp-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hcsp-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49554844?'},
#   'repo': {'id': 196731863,
#    'name': 'hcsp/fix-commons-lang-pom',
#    'url': 'https://api.github.com/repos/hcsp/fix-commons-lang-pom'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/hcsp/fix-commons-lang-pom/issues/101',
#     'repository_url': 'https://api.github.com/repos/hcsp/fix-commons-lang-pom',
#     'labels_url': 'https://api.github.com/repos/hcsp/fix-commons-lang-pom/issues/101/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/hcsp/fix-commons-lang-pom/issues/101/comments',
#     'events_url': 'https://api.github.com/repos/hcsp/fix-commons-lang-pom/issues/101/events',
#     'html_url': 'https://github.com/hcsp/fix-commons-lang-pom/pull/101',
#     'id': 573268519,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzgxODMwNTgx',
#     'number': 101,
#     'title': '修复commons-lang项目的pom文件',
#     'user': {'login': 'nicknessii',
#      'id': 58057685,
#      'node_id': 'MDQ6VXNlcjU4MDU3Njg1',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/58057685?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/nicknessii',
#      'html_url': 'https://github.com/nicknessii',
#      'followers_url': 'https://api.github.com/users/nicknessii/followers',
#      'following_url': 'https://api.github.com/users/nicknessii/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/nicknessii/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/nicknessii/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/nicknessii/subscriptions',
#      'organizations_url': 'https://api.github.com/users/nicknessii/orgs',
#      'repos_url': 'https://api.github.com/users/nicknessii/repos',
#      'events_url': 'https://api.github.com/users/nicknessii/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/nicknessii/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1554351377,
#       'node_id': 'MDU6TGFiZWwxNTU0MzUxMzc3',
#       'url': 'https://api.github.com/repos/hcsp/fix-commons-lang-pom/labels/is:answer',
#       'name': 'is:answer',
#       'color': '008672',
#       'default': False,
#       'description': None}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2020-02-29T10:21:45Z',
#     'updated_at': '2020-02-29T10:21:46Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'pull_request': {'url': 'https://api.github.com/repos/hcsp/fix-commons-lang-pom/pulls/101',
#      'html_url': 'https://github.com/hcsp/fix-commons-lang-pom/pull/101',
#      'diff_url': 'https://github.com/hcsp/fix-commons-lang-pom/pull/101.diff',
#      'patch_url': 'https://github.com/hcsp/fix-commons-lang-pom/pull/101.patch'},
#     'body': '<!--- 你要打开的这个Pull request(PR)的类型是？默认是题目解答，如果你正在修复当前的仓库的缺陷，请选择对应的类型 -->\r\n\r\n- [x] 这个PR解答了当前仓库中的题目（机器人会自动判题并合并当前PR）\r\n- [ ] 这个PR修复了当前仓库中的一些代码缺陷（机器人不会判题，而是由管理员来处理当前PR）\r\n\r\n'},
#    'comment': {'url': 'https://api.github.com/repos/hcsp/fix-commons-lang-pom/issues/comments/592929767',
#     'html_url': 'https://github.com/hcsp/fix-commons-lang-pom/pull/101#issuecomment-592929767',
#     'issue_url': 'https://api.github.com/repos/hcsp/fix-commons-lang-pom/issues/101',
#     'id': 592929767,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU5MjkyOTc2Nw==',
#     'user': {'login': 'hcsp-bot',
#      'id': 49554844,
#      'node_id': 'MDQ6VXNlcjQ5NTU0ODQ0',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/49554844?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/hcsp-bot',
#      'html_url': 'https://github.com/hcsp-bot',
#      'followers_url': 'https://api.github.com/users/hcsp-bot/followers',
#      'following_url': 'https://api.github.com/users/hcsp-bot/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/hcsp-bot/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/hcsp-bot/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/hcsp-bot/subscriptions',
#      'organizations_url': 'https://api.github.com/users/hcsp-bot/orgs',
#      'repos_url': 'https://api.github.com/users/hcsp-bot/repos',
#      'events_url': 'https://api.github.com/users/hcsp-bot/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/hcsp-bot/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-02-29T10:21:46Z',
#     'updated_at': '2020-02-29T10:21:46Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': ':tada: 感谢提交Pull Request！请稍等片刻，我们已经将其提交到CI进行检查，一旦有结果会立即通知您！'}},
#   'public': True,
#   'created_at': '2020-02-29T10:21:46Z',
#   'org': {'id': 47730780,
#    'login': 'hcsp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/hcsp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47730780?'}},
#  {'id': '11642942434',
#   'type': 'CreateEvent',
#   'actor': {'id': 17725280,
#    'login': 'gaozhao1989',
#    'display_login': 'gaozhao1989',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gaozhao1989',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17725280?'},
#   'repo': {'id': 243945687,
#    'name': 'gaozhao1989/test-vue-bootstrap-project',
#    'url': 'https://api.github.com/repos/gaozhao1989/test-vue-bootstrap-project'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-29T10:21:46Z'},
#  {'id': '11642942429',
#   'type': 'PushEvent',
#   'actor': {'id': 42879136,
#    'login': 'BryanBenavente',
#    'display_login': 'BryanBenavente',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/BryanBenavente',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42879136?'},
#   'repo': {'id': 243928622,
#    'name': 'BryanBenavente/demo-travis',
#    'url': 'https://api.github.com/repos/BryanBenavente/demo-travis'},
#   'payload': {'push_id': 4699218464,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ec8122856e617cb4ca8b32bfdf69baa6d50d5c71',
#    'before': 'b62e05ac180151415b1ca2f1125385f0e3bab21c',
#    'commits': [{'sha': 'ec8122856e617cb4ca8b32bfdf69baa6d50d5c71',
#      'author': {'email': 'bryan.benavente@vallegrande.edu.pe',
#       'name': 'Bryan.Benavente'},
#      'message': 'travis 5',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/BryanBenavente/demo-travis/commits/ec8122856e617cb4ca8b32bfdf69baa6d50d5c71'}]},
#   'public': True,
#   'created_at': '2020-02-29T10:21:46Z'},
#  {'id': '11642942428',
#   'type': 'PushEvent',
#   'actor': {'id': 20233085,
#    'login': 'benz0li',
#    'display_login': 'benz0li',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/benz0li',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20233085?'},
#   'repo': {'id': 238884712,
#    'name': 'b-data/rocker-versioned',
#    'url': 'https://api.github.com/repos/b-data/rocker-versioned'},
#   'payload': {'push_id': 4699218460,
#    'size': 5,
#    'distinct_size': 5,
#    'ref': 'refs/heads/master',
#    'head': 'e3d979b489c8f95e40a9fbafaac43a5eff12c6a7',
#    'before': 'c163f691d44d16ecee0c6a6b1f2d53e881f83bfd',
#    'commits': [{'sha': '9aaf3363abde27e4aa29931e11af9ff93dd086f1',
#      'author': {'email': 'olivier.benz@b-data.ch', 'name': 'Olivier Benz'},
#      'message': 'Update .gitlab-ci.yml\n\n- Trigger dependent builds',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/b-data/rocker-versioned/commits/9aaf3363abde27e4aa29931e11af9ff93dd086f1'},
#     {'sha': '200ec14f2a756a45bf131b40fa0cb7bd81fcbf05',
#      'author': {'email': 'olivier.benz@b-data.ch', 'name': 'Olivier Benz'},
#      'message': 'Freeze R version 3.6.2',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/b-data/rocker-versioned/commits/200ec14f2a756a45bf131b40fa0cb7bd81fcbf05'},
#     {'sha': 'e9f9aeaadac715d64c7ef0d80047f2b129270b9e',
#      'author': {'email': 'olivier.benz@b-data.ch', 'name': 'Olivier Benz'},
#      'message': "Merge branch 'freeze-version'",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/b-data/rocker-versioned/commits/e9f9aeaadac715d64c7ef0d80047f2b129270b9e'},
#     {'sha': '5238fef7d9a7a0fd68f820cb3a5ff64330467c3f',
#      'author': {'email': 'olivier.benz@b-data.ch', 'name': 'Olivier Benz'},
#      'message': 'Update R to version 3.6.3',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/b-data/rocker-versioned/commits/5238fef7d9a7a0fd68f820cb3a5ff64330467c3f'},
#     {'sha': 'e3d979b489c8f95e40a9fbafaac43a5eff12c6a7',
#      'author': {'email': 'olivier.benz@b-data.ch', 'name': 'Olivier Benz'},
#      'message': 'Leave mode R_VERSION_UPDATE',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/b-data/rocker-versioned/commits/e3d979b489c8f95e40a9fbafaac43a5eff12c6a7'}]},
#   'public': True,
#   'created_at': '2020-02-29T10:21:46Z',
#   'org': {'id': 23398153,
#    'login': 'b-data',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/b-data',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23398153?'}},
#  {'id': '11642942427',
#   'type': 'CreateEvent',
#   'actor': {'id': 53108186,
#    'login': 'codestar-github-bot-1',
#    'display_login': 'codestar-github-bot-1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/codestar-github-bot-1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53108186?'},
#   'repo': {'id': 243947411,
#    'name': 'devhub-blue-sea/org-public-empty-repo-ap-southeast-2',
#    'url': 'https://api.github.com/repos/devhub-blue-sea/org-public-empty-repo-ap-southeast-2'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'Empty Repository created by CFN',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-29T10:21:46Z',
#   'org': {'id': 53108288,
#    'login': 'devhub-blue-sea',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/devhub-blue-sea',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53108288?'}}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests

r = requests.get('https://cat-fact.herokuapp.com/facts')
r.text


import json

json.loads(r.text)
# Out:
# {'all': [{'_id': '58e008ad0aac31001185ed0c',
#    'text': "The frequency of a domestic cat's purr is the same at which muscles and bones repair themselves.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 10,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b4911940508220014ccfe94',
#    'text': 'By the time a cat is 9 years old, it will only have been awake for three years of its life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '59a60b8e6acf530020f3586e',
#    'text': 'Cat owners are 17% more likely to have a graduate degree than non cat owners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '591d9b2f227c1a0020d26823',
#    'text': 'Every year, nearly four million cats are eaten in China as a delicacy.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a090aac31001185ed16',
#    'text': 'Cats make more than 100 different sounds whereas dogs make around 10.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58cafac6ffae36001108d586',
#    'text': 'Cats have fur',
#    'type': 'cat',
#    'user': {'_id': '58c86fe52341fc0011d7b151',
#     'name': {'first': 'Alex', 'last': 'Simon'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475c86a99c3f00140fe4cf',
#    'text': "The Manx hails from the Isle of Man in the Irish Sea, and many Manx are tailless, a condition believed to have been caused by a dominant genetic mutation that spread among the island's cat population.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c489117e4f6130014c987b9',
#    'text': 'Leonardo da Vinci created a series of drawings titled "Study of Cat Movements and Positions", which consists of more than twenty drawings of cats and lions lying a sleep, sitting, playing, and fighting.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60982ce549020014533033',
#    'text': 'The Chartreux is distinguished by a woolly blue-grey coat, a robust body poised over small paws, and full cheeks with a mouth that always appear to be smiling.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609852e549020014533036',
#    'text': "While Chartreux cats aren't very vocal, they are sociable and communicate through eye contact and body language.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60999ae549020014533038',
#    'text': 'Cats love playing with yarn, ribbons, and fishing-rode style toys. However, cats should not be left alone with anything that they could get tangled in.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a02e549020014533039',
#    'text': "All Scottish Folds descended from Susie, a white barn cat discovered in Scotland in the early 1960s. Susie sported the breed's folded ears – the result of a genetic mutation – and passed on the trait through breeding.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a90e54902001453303a',
#    'text': 'Mark Twain was undeniably an ailurophile. He had up to 19 cats at one time and gave them such memorable names as Beelzebub, Buffalo Bill, and Soapy Sal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c35cc2d7a200140f67ea',
#    'text': 'If you really want to treat your cat, get some lactose-free milk at the grocery store and offer some to the kitty.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c47dc2d7a200140f67ee',
#    'text': 'Abraham Lincoln, being the ailurophile that he was, once rescued three stray kittens and ensured that they were fed and found homes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c4eec2d7a200140f67ef',
#    'text': 'The Sphynx was originally known as the Canadian Hairless Cat. The breed originated in Toronto, and was renamed to Sphynx, a nod to the famous limestone sculpture in the Egyptian Desert.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c6a104fc2d7a200140f699f',
#    'text': 'A cat’s spine can rotate more than the spines of most other animals, and their vertebrae have a special, flexible, elastic cushioning on the disks, which gives it even more flexibility.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c72d9b651021f001415f00c',
#    'text': 'Cats have been domesticated for around 4,000 years. While they were once valued for their hunting abilities, they are now valued for their companionship and loving behavior.',
#    'type': 'cat',
#    'user': {'_id': '5c6fd96df4256a001498a73f',
#     'name': {'first': 'Hedvig', 'last': 'Annersten'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c72dbd851021f001415f010',
#    'text': 'The most popular pedigreed cat in North America is the Persian cat, followed by the Main Coon and the Siamese cat.',
#    'type': 'cat',
#    'user': {'_id': '5c72dbb751021f001415f00f',
#     'name': {'first': 'Hedvig', 'last': 'Annersten'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38afd60f1c57001592f127',
#    'type': 'cat',
#    'text': 'In the early 1980s, a Chinchilla Persian cat named Jemari Sanquist mated with a Lilac Burmese named Bambino Lilac Fabergé, producing the Burmilla breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0310f1c57001592f128',
#    'type': 'cat',
#    'text': 'Scratching allows a cat to shed the outer layers of her claws, mark her territory, and stretch her body. Rather than discouraging the scratching behavior altogether, try redirecting your cat to a few scratching posts placed strategically around your home.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0c40f1c57001592f129',
#    'type': 'cat',
#    'text': 'The elegant Balinese is a longhaired variety of the Siamese, and like the Siamese, this stunning breed is sociable and intelligent. The breed was named for the grace of the dancers on the island of Bali in Indonesia.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b16c0f1c57001592f12b',
#    'type': 'cat',
#    'text': 'A large number of cats inhabit the Largo di Torre Argentina, an ancient Roman temple site near where Caesar was killed. Local volunteers care for the cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2270f1c57001592f12d',
#    'type': 'cat',
#    'text': 'Among the British government officials who keep things running smoothly at 10 Downing Street is Larry, a cat that holds the distinguished position of Chief Mouser. Larry\'s duties, according to the U.K. government, include "greeting guests", "testing antique furniture for napping quality", and "contemplating a solution to the mouse occupancy of the house.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b27b0f1c57001592f12f',
#    'type': 'cat',
#    'text': 'The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b29f0f1c57001592f130',
#    'type': 'cat',
#    'text': 'The Abyssinian, the Siamese, and the American Shorthair were crossbred to produce the Ocicat breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'type': 'cat',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5de780600013130015a3ccaf',
#    'type': 'cat',
#    'text': 'About one in two cats respond to catnip, and only develop a sensitivity to it at around 3 to 6 months of age.',
# ...
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609945e549020014533037',
#    'text': 'Do you ever wake up in the middle of the night and find your cat sleeping on your head? Cat behavioral experts believe that cats are drawn to the warmth and the familiar scent of the owner. Resting on your head also keeps kitty safe from your arms and legs if you toss and turn through the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c7408a14dd87d001490f02b',
#    'text': "The cheetah is the only cat that doesn't have retractable claws.",
#    'type': 'cat',
#    'user': {'_id': '5c72e94751021f001415f012',
#     'name': {'first': 'Tests', 'last': 'HiQ'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c75f56272681400147b988a',
#    'text': 'There are only two escalators in the state of Wyoming.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c84248f731a60001540a193',
#    'text': 'When a cat lifts its butt in the air when scratched, it is a sign that your feline is giving your pats an A+. However, if you have a female kitty who hasn\'t been spayed, "elevator butt" could be a sign that she\'s ready to mate. The proper name for this stance is lordosis, and cats adopt it when they\'re in heat.',
#    'type': 'cat',
#    'user': {'_id': '5c7da4bd70008708fb17c88f',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c87d03dec1e5c0aa37e0a6b',
#    'type': 'cat',
#    'text': 'On October 24, 1963, a tuxedo cat named Félicette entered outer space aboard a French Véronique AG1 rocket and made feline history. Félicette returned from the 15-minute trip in once piece and earned the praise of French scientists, who said she made "a valuable contribution to research.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd42b77cfdf230015bd7a45',
#    'text': 'Cats can sense distress from a human being.',
#    'type': 'cat',
#    'user': {'_id': '5cd42b40cfdf230015bd7a44',
#     'name': {'first': 'Chloe', 'last': 'Simmons'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd86b0e1dc6d50015ec2f08',
#    'text': 'Norwegian Forest Cats are usually very people friendly.',
#    'type': 'cat',
#    'user': {'_id': '5cd86adb1dc6d50015ec2f07',
#     'name': {'first': 'Shay', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1d40f1c57001592f12c',
#    'type': 'cat',
#    'text': "During the heat of the summer, set out an extra bowl of water and place ice cubes in it to keep it cold and refreshing. Cats love to lie on cool surfaces when it's hot—if you don't have an tile in your home, consider buying a few ceramic tiles from a home improvement store for your cat to rest on.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'type': 'cat',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to 14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5e10d7841c78ab0015bc5b15',
#    'type': 'cat',
#    'text': 'Some cats do not eat fish.',
#    'user': {'_id': '5e10d6e51c78ab0015bc5b14',
#     'name': {'first': 'Max', 'last': 'Bilohatnyuk'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e19da391fd6150015fa7356',
#    'type': 'cat',
#    'text': '"Cats can hear the ultrasonic noises that rodents and dolphins make to communicate.".',
#    'user': {'_id': '5e19d99e1fd6150015fa7353',
#     'name': {'first': 'Crystal Gale', 'last': 'Scott'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e1efba858449a0015ce4783',
#    'type': 'cat',
#    'text': '"A house cat is faster than Usain Bolt.".',
#    'user': {'_id': '5e1efb5958449a0015ce4781',
#     'name': {'first': 'oyaji', 'last': '55'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e239999dc76630015d4c5e2',
#    'type': 'cat',
#    'text': 'Cats see only on blue and yellow.',
#    'user': {'_id': '5e239963dc76630015d4c5e1',
#     'name': {'first': 'Eduardo', 'last': 'P. Gomez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e27232ec71d0900152d8518',
#    'type': 'cat',
#    'text': 'Cats are dumb.',
#    'user': {'_id': '5e272323c71d0900152d8517',
#     'name': {'first': 'Andrew', 'last': 'Steele'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e2f9f1ade397c00152dd552',
#    'type': 'cat',
#    'text': 'Cat.',
#    'user': {'_id': '5e2f9f0ede397c00152dd551',
#     'name': {'first': 'bah', 'last': 'godam99'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e2f9f23de397c00152dd553',
#    'type': 'cat',
#    'text': 'Sleep.',
#    'user': {'_id': '5e2f9f0ede397c00152dd551',
#     'name': {'first': 'bah', 'last': 'godam99'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e3382ccd7ac48001509e153',
#    'type': 'cat',
#    'text': 'Cat is an animal.',
#    'user': {'_id': '5e3381f3d7ac48001509e151',
#     'name': {'first': 'Dicka', 'last': 'Ismaji'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e344e7acd8efb0015ae3055',
#    'type': 'cat',
#    'text': 'Cat live, on average, for about 7-8 years.',
#    'user': {'_id': '5e344e3ccd8efb0015ae3054',
#     'name': {'first': 'RYAN', 'last': 'STULTZ'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e3534d8cd8efb0015ae305c',
#    'type': 'cat',
#    'text': 'Hi.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e35436d11559000151bf453',
#    'type': 'cat',
#    'text': '123.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e355bf411559000151bf454',
#    'type': 'cat',
#    'text': 'Fgf.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e380ea32035630015618254',
#    'type': 'cat',
#    'text': 'Asd.',
#    'user': {'_id': '5e380e9b2035630015618253',
#     'name': {'first': 'dm', 'last': 'max'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e56fdf375991a0015429ffc',
#    'type': 'cat',
#    'text': 'Bbb.',
#    'user': {'_id': '5e56fddd75991a0015429ffb',
#     'name': {'first': 'Cristian', 'last': 'Salcedo'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e353507cd8efb0015ae305d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e4c4e10a38ae60015b04a7e',
#    'type': 'cat',
#    'text': "Cats think humans have night vision too, so when we step on their tail in the middle of the night, they think it's on purpose.",
#    'user': {'_id': '5e4c4dc5a38ae60015b04a7d',
#     'name': {'first': 'Nathaniel J', 'last': 'McDermott'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e546a054e83e80015a0e320',
#    'type': 'cat',
#    'text': "Contrary to popular belief, some cats actually don't mind water. The hairless Sphynx cat enjoys it, especially if it is warm.",
#    'user': {'_id': '5e54675a4e83e80015a0e313',
#     'name': {'first': "L'hibou", 'last': 'Ambigu'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}
